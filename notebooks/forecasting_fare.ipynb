# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import shuffle

# %%
df = pd.read_pickle("dfnew.pkl")

# %%
df.shape
# Out:
# (2249711, 23)

# %%
df = shuffle(df)

# %%
df.head()
# Out:
#         lpep_pickup_datetime lpep_dropoff_datetime  RatecodeID  PULocationID  \
# 1988776  2017-02-12 21:55:49   2017-02-12 22:02:09           1            74
# 650356   2017-09-01 13:29:11   2017-09-01 13:31:29           1           145
# 822186   2017-07-31 20:21:12   2017-07-31 20:23:55           1           173
# 1504053  2017-04-18 22:18:08   2017-04-18 22:23:03           1           116
# 2039479  2017-02-05 16:53:48   2017-02-05 16:55:30           1            41
#
#          DOLocationID  passenger_count  trip_distance  fare_amount  extra  \
# 1988776            75                1            1.1          6.5    0.5
# 650356            145                1            0.5          4.0    0.0
# 822186             56                1            0.5          4.0    0.5
# 1504053           166                1            0.9          5.5    0.5
# 2039479            41                1            0.3          3.5    0.0
#
#          mta_tax   ...     total_amount  payment_type  trip_type  \
# 1988776      0.5   ...             7.80             2        1.0
# 650356       0.5   ...             6.80             1        1.0
# 822186       0.5   ...             5.30             2        1.0
# 1504053      0.5   ...             6.86             1        1.0
# 2039479      0.5   ...             4.30             2        1.0
#
#          trip_duration  month  day  total_custom  weekend_Trip  hour  airport
# 1988776       6.333333      2    6          7.80             1    21        0
# 650356        2.300000      9    4          6.80             0    13        0
# 822186        2.716667      7    0          5.30             0    20        0
# 1504053       4.916667      4    1          6.86             0    22        0
# 2039479       1.700000      2    6          4.30             1    16        0
#
# [5 rows x 23 columns]

# %%
df['lpep_pickup_datetime'] = pd.to_datetime(df['lpep_pickup_datetime'])
df['new_date_column'] = df['lpep_pickup_datetime'].dt.date

# %%
df.head()
# Out:
#         lpep_pickup_datetime lpep_dropoff_datetime  RatecodeID  PULocationID  \
# 1988776  2017-02-12 21:55:49   2017-02-12 22:02:09           1            74
# 650356   2017-09-01 13:29:11   2017-09-01 13:31:29           1           145
# 822186   2017-07-31 20:21:12   2017-07-31 20:23:55           1           173
# 1504053  2017-04-18 22:18:08   2017-04-18 22:23:03           1           116
# 2039479  2017-02-05 16:53:48   2017-02-05 16:55:30           1            41
#
#          DOLocationID  passenger_count  trip_distance  fare_amount  extra  \
# 1988776            75                1            1.1          6.5    0.5
# 650356            145                1            0.5          4.0    0.0
# 822186             56                1            0.5          4.0    0.5
# 1504053           166                1            0.9          5.5    0.5
# 2039479            41                1            0.3          3.5    0.0
#
#          mta_tax       ...         payment_type  trip_type  trip_duration  \
# 1988776      0.5       ...                    2        1.0       6.333333
# 650356       0.5       ...                    1        1.0       2.300000
# 822186       0.5       ...                    2        1.0       2.716667
# 1504053      0.5       ...                    1        1.0       4.916667
# 2039479      0.5       ...                    2        1.0       1.700000
#
#          month  day  total_custom  weekend_Trip  hour  airport  \
# 1988776      2    6          7.80             1    21        0
# 650356       9    4          6.80             0    13        0
# 822186       7    0          5.30             0    20        0
# 1504053      4    1          6.86             0    22        0
# 2039479      2    6          4.30             1    16        0
#
#          new_date_column
# 1988776       2017-02-12
# 650356        2017-09-01
# 822186        2017-07-31
# 1504053       2017-04-18
# 2039479       2017-02-05
#
# [5 rows x 24 columns]

# %%
df_1 = df[['day','month','new_date_column','fare_amount','trip_distance']]

# %%
df_1.head()
df_1.shape
# Out:
# (2249711, 5)

# %%
df_1.head()
# Out:
#          day  month new_date_column  fare_amount  trip_distance
# 1988776    6      2      2017-02-12          6.5            1.1
# 650356     4      9      2017-09-01          4.0            0.5
# 822186     0      7      2017-07-31          4.0            0.5
# 1504053    1      4      2017-04-18          5.5            0.9
# 2039479    6      2      2017-02-05          3.5            0.3

# %%
total_fare = (df_1.groupby(['new_date_column','day','month'])["fare_amount","trip_distance"].sum().reset_index())

# %%
total_fare.shape
# Out:
# (365, 5)

# %%
total_fare.head()
# Out:
#   new_date_column  day  month  fare_amount  trip_distance
# 0      2017-01-01    6      1     97308.74        24771.4
# 1      2017-01-02    0      1     54059.56        12880.2
# 2      2017-01-03    1      1     67148.02        15182.4
# 3      2017-01-04    2      1     71893.70        16093.1
# 4      2017-01-05    3      1     75570.80        17015.5

# %%
tem = total_fare[total_fare['month']!=12][['day','month','trip_distance']]
print(tem)
# Out:
#      day  month  trip_distance
# 0      6      1        24771.4
# 1      0      1        12880.2
# 2      1      1        15182.4
# 3      2      1        16093.1
# 4      3      1        17015.5
# 5      4      1        18125.6
# 6      5      1        16924.4
# 7      6      1        17030.1
# 8      0      1        17458.5
# 9      1      1        15841.9
# 10     2      1        16523.0
# 11     3      1        16928.4
# 12     4      1        20518.3
# 13     5      1        22186.6
# 14     6      1        19937.7
# 15     0      1        12973.3
# 16     1      1        15642.3
# 17     2      1        15636.9
# 18     3      1        17154.1
# 19     4      1        19702.1
# 20     5      1        21521.7
# 21     6      1        17988.8
# 22     0      1        16089.0
# 23     1      1        15808.7
# 24     2      1        16653.8
# 25     3      1        18096.3
# 26     4      1        20988.3
# 27     5      1        23301.7
# 28     6      1        19893.5
# 29     0      1        15575.4
# ..   ...    ...            ...
# 304    2     11        13222.4
# 305    3     11        13692.9
# 306    4     11        15959.7
# 307    5     11        17789.1
# 308    6     11        13720.1
# 309    0     11        12662.0
# 310    1     11        12400.9
# 311    2     11        12715.5
# 312    3     11        14041.6
# 313    4     11        16082.6
# 314    5     11        16457.3
# 315    6     11        14318.9
# 316    0     11        12257.8
# 317    1     11        12273.8
# 318    2     11        12988.2
# 319    3     11        14337.0
# 320    4     11        15646.6
# 321    5     11        17138.7
# 322    6     11        13773.4
# 323    0     11        11977.6
# 324    1     11        12283.0
# 325    2     11        13452.5
# 326    3     11        11319.3
# 327    4     11         9777.5
# 328    5     11        12241.7
# 329    6     11        12261.4
# 330    0     11        11311.3
# 331    1     11        10941.6
# 332    2     11        11818.9
# 333    3     11        12866.3
#
# [334 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
decision = total_fare[['fare_amount']]
features = total_fare[['day', 'month', 'trip_distance']]
train = total_fare[total_fare['month']!=12][['day','month','trip_distance']]
train_d = total_fare[total_fare['month']!=12][['fare_amount']]
test = total_fare[total_fare['month']==12][['day','month','trip_distance']]
test_d = total_fare[total_fare['month']==12][['fare_amount']]

# %%
from sklearn.ensemble import RandomForestRegressor
RF = RandomForestRegressor()
rfr = RF.fit(train, train_d.values.ravel())

# %%
test_rfr = RF.predict(test)
test_rfr #forecasting fare_amount
# Out:
# array([67525.991, 73731.87 , 60307.133, 52552.257, 57923.945, 58125.47 ,
#        58277.743, 66155.076, 65980.746, 57309.666, 53918.443, 55080.453,
#        57245.534, 58458.054, 61696.541, 72614.222, 57736.113, 54719.292,
#        57047.923, 59159.175, 63958.852, 66006.195, 56750.345, 46632.086,
#        35316.689, 35316.689, 45603.252, 45125.454, 50926.902, 44699.174,
#        57263.308])

# %%
test_d # fare_amount
# Out:
#      fare_amount
# 334     70622.61
# 335     75151.50
# 336     59013.25
# 337     51673.30
# 338     58848.93
# 339     58201.90
# 340     60819.90
# 341     68873.35
# 342     63169.70
# 343     52557.91
# 344     53534.20
# 345     55402.10
# 346     58712.60
# 347     60992.27
# 348     67489.10
# 349     72348.29
# 350     59262.28
# 351     54286.11
# 352     56855.70
# 353     59749.24
# 354     63155.54
# 355     65637.04
# 356     53480.40
# 357     48365.06
# 358     30396.76
# 359     37463.50
# 360     44806.71
# 361     47192.07
# 362     52386.30
# 363     45160.38
# 364     53848.86

# %%
plt.figure(figsize=(10,10))
sns.pointplot(x='new_date_column',y='fare_amount',data=total_fare,kind='point',hue='month')
plt.xlabel('new_date_column',fontsize=16)
plt.ylabel('fare_amount',fontsize=16)
# Out:
# Text(0,0.5,'fare_amount')

# %%
lines = total_fare.plot.line(x='new_date_column', y='fare_amount')

# %%
lines = test_d.plot.line()

# %%
test_d['fare_amount']=test_rfr

# %%
test_d.head()
# Out:
#      fare_amount
# 334    67525.991
# 335    73731.870
# 336    60307.133
# 337    52552.257
# 338    57923.945

# %%
lines = test_d.plot.line()
